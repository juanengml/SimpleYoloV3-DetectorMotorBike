# %%
import os 
import autogluon as ag
from autogluon import ObjectDetection as task
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))

# %%
# !pip install -r requerimentes.txt
# Out:
# ...
#   Using cached autogluon-0.0.10-py3-none-any.whl (388 kB)
# ...
#   Using cached bcrypt-3.1.7-cp34-abi3-manylinux1_x86_64.whl (56 kB)
# ...
#   Using cached boto3-1.14.2-py2.py3-none-any.whl (128 kB)
# ...
#   Using cached botocore-1.17.2-py2.py3-none-any.whl (6.3 MB)
# ...
#      |████████████████████████████████| 64.7 MB 119.9 MB/s eta 0:00:01
# ...
#   Using cached certifi-2020.4.5.2-py2.py3-none-any.whl (157 kB)
# ...
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# ...
#   Using cached cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# ...
#   Using cached ConfigSpace-0.4.10.tar.gz (882 kB)
# ...
#   Using cached console_logging-0.0.5.0-py2.py3-none-any.whl (5.3 kB)
# ...
#   Using cached contextvars-2.4.tar.gz (9.6 kB)
# ...
#   Using cached cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# ...
#      |████████████████████████████████| 2.0 MB 90.9 MB/s eta 0:00:01
# ...
#   Using cached dask-2.18.1-py3-none-any.whl (823 kB)
# ...
#   Using cached distributed-2.18.0-py3-none-any.whl (640 kB)
# ...

# %%
savefile = 'model.pkl'
#detector.save(savefile)

from autogluon import Detector
new_detector = Detector.load(savefile)

# %%
image = '009944.jpg'
data_root = os.path.join("./", "tiny_motorbike")

image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = new_detector.predict(image_path)
